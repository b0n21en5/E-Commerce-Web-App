# %%
import requests
import pandas as pd




headers = {
    'authority': 'www.autolist.com',
    'accept': '*/*',
    'accept-language': 'en-US,en;q=0.9',
    'cookie': 'ec=eyJlZGdlVXNlckFnZW50IjoiTW96aWxsYS81LjAgKFdpbmRvd3MgTlQgMTAuMDsgV2luNjQ7IHg2NCkgQXBwbGVXZWJLaXQvNTM3LjM2IChLSFRNTCwgbGlrZSBHZWNrbykgQ2hyb21lLzEwNC4wLjAuMCBTYWZhcmkvNTM3LjM2In0=; client_guid_timestamp=c4777881-1d6d-4546-93b9-56c09d2a118c.1664260510280; _fbp=fb.1.1664260511481.1704299678; _pbjs_userid_consent_data=3524755945110770; _pubcid=f98796da-97c6-4aea-b7b5-cfb862901945; __gads=ID=6e5421d35c1a68d7:T=1664260512:S=ALNI_Mb5md167rVl1rJrVnvK2LTkZedJ0Q; pbjs-unifiedid=^%^7B^%^22TDID^%^22^%^3A^%^22e5d643e7-a421-4285-9ddb-c4ea7062ad7f^%^22^%^2C^%^22TDID_LOOKUP^%^22^%^3A^%^22TRUE^%^22^%^2C^%^22TDID_CREATED_AT^%^22^%^3A^%^222022-08-27T06^%^3A35^%^3A14^%^22^%^7D; panoramaId_expiry=1664865314516; _cc_id=606aa7d99bfdae42b3cefde8ac153644; panoramaId=afba09fa9566548c5e02b54ee44b16d53938627373ea2d6cb0d60761fc64ecb5; _gcl_au=1.1.949515730.1664260558; sp-nuid=9729a8bf-7cd8-4b31-a0cf-ffab77531f8c; _sp_ses.8ca5=*; _gid=GA1.2.644872854.1664372952; __gpi=UID=000009e49fede09e:T=1664260512:RT=1664372955:S=ALNI_MZ99J8HWK8sKcUUDigDXrkSugURqQ; AMP_TOKEN=^%^24NOT_FOUND; _ga=GA1.2.599645584.1664260511; _ga_KKZ1EQJKEV=GS1.1.1664372954.2.1.1664372998.0.0.0; cto_bundle=WWXLF193c2pQVEN6MDh3bkh4amx0OG94JTJGcXdGN1dsOHdPak03VGFwZUJaJTJCJTJCeEZ3Q2pJTUYlMkJ3cDVqbEFzWUxrWHROUjBROUglMkJIZHRaNE1hb1RVTmE5aTFPZlNsRVJ6dk42TDZIVVE0bUoyRHMzUU0xSVFLY0pGRmFGRU9KWjBRJTJCZCUyRmMyN1BrbSUyQk5Ta1cwYiUyQmxhY1hyZnlRUHclM0QlM0Q; _gat=1; _sp_id.8ca5=b49de10e-2003-4ccc-9a7f-1f487a579b25.1664260511.4.1664373119.1664329167.5e18b76d-3643-4db8-b3ca-4e633c5ba18e',
    'if-none-match': 'W/^\\^12c6f78e76cc8e42ed461fb913f35899^\\^',
    'referer': 'https://www.autolist.com/listings',
    'sec-ch-ua': '^\\^Chromium^\\^;v=^\\^104^\\^, ^\\^',
    'sec-ch-ua-mobile': '?0',
    'sec-ch-ua-platform': '^\\^Windows^\\^',
    'sec-fetch-dest': 'empty',
    'sec-fetch-mode': 'cors',
    'sec-fetch-site': 'same-origin',
    'user-agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/104.0.0.0 Safari/537.36',
    'x-autolist-session-guid': 'f33bf802-e87f-45a7-a8ca-5263c152e89d',
    'x-requested-with': 'XMLHttpRequest',
}

model = []
mileage = []
year = []
price = []
dealer_name = []
city = []
state  = []



for i in range(1,6):
    params = (
        ('make', 'Tesla'),
        ('location', 'Washington,^%^20DC'),
        ('latitude', '38.9071923'),
        ('longitude', '-77.0368707'),
        ('radius', '50'),
        ('page', str(i)),
    )

    response = requests.get('https://www.autolist.com/api/cwv/seo/listings', headers=headers, params=params)
    
    res_json = response.json()['search_results']
    
    
    for res in res_json:
        model.append(res['model'])
        mileage.append(res['mileage'])
        year.append(res['year'])
        price.append(res['price'])
        dealer_name.append(res['dealer_name'])
        city.append(res['city'])
        state.append(res['state'])
        
        
tesla_cars_df = pd.DataFrame({'Model':model,'Mileage':mileage,'Year':year,'Dealer_name':dealer_name,'City':city,'State':state})

# %%
tesla_cars_df
# Out:
#       Model        Mileage  Year  \
# 0   Model S  101,020 Miles  2014
# 1   Model 3   13,764 Miles  2020
# 2   Model 3   69,648 Miles  2018
# 3   Model 3    8,593 Miles  2020
# 4   Model 3   22,165 Miles  2021
# ..      ...            ...   ...
# 95  Model S   27,448 Miles  2019
# 96  Model 3    8,788 Miles  2022
# 97  Model S   51,040 Miles  2017
# 98  Model 3   31,045 Miles  2020
# 99  Model Y   24,740 Miles  2020
#
#                                           Dealer_name           City State
# 0                                  Capital Auto Sales      Chantilly    VA
# 1                                  Herb Gordon Subaru  Silver Spring    MD
# 2                         Heritage Toyota Catonsville      Baltimore    MD
# 3   CarMax Dulles - Now Offering Curbside Pickup A...       Sterling    VA
# 4   CarMax White Marsh - Now Offering Curbside Pickup    White Marsh    MD
# ..                                                ...            ...   ...
# ...

# %%
tesla_cars_df.to_csv('tesla_cars.csv', index=False)
